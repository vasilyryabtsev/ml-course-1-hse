# %%
# %pylab inline 
# magic function
import pandas as pd
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
#!pip install wget
#import wget 
#wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %%
# 1.1
data = pd.read_excel("end_seminar.xlsx")
data.tail(10)
# Out:
#                   timestamp                                id  rating  \
# 351 2020-05-18 23:58:33.903  8fe79f84f36e3a5d2d6745621321302c    1016
# 352 2020-05-18 23:59:20.831  f93afd8e92c336b471aa3bbbc579aefe    1298
# 353 2020-05-18 23:59:28.998  9963fc00d9405a35b894cc04a7e19855    1135
# 354 2020-05-19 08:55:39.509  98c5a2548d93f26bd4195466e93178b3    1035
# 355 2020-05-19 18:58:06.283  ba298cbd9be59b84bab33325e956f27e    1155
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 351       NaN    NaN                 Безопасность компьютерных систем
# ...

# %%
# 1.2
data[data['17_group'].notnull()].shape[0]
# Out:
# 138

# %%
data['percentile'].unique().shape[0] == data['percentile'].shape[0]
# Out:
# False

# %%
data.shape
# Out:
# (361, 16)

# %%
#1.3
data.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %%
data[data.select_dtypes(include='object').columns] = data[data.select_dtypes(include='object').columns].fillna('')
data[data.select_dtypes(include='float64').columns] = data[data.select_dtypes(include='float64').columns].fillna(0)

# %%
data.isna().sum()
# Out:
# timestamp        0
# id               0
# rating           0
# 18_group         0
# is_mi            0
# fall_1           0
# fall_2           0
# fall_3           0
# spring_1         0
# spring_2         0
# spring_3         0
# is_first_time    0
# percentile       0
# 17_group         0
# blended          0
# is_ml_student    0
# dtype: int64

# %%
data.dtypes
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# 18_group                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# 17_group                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %%
data.shape
# Out:
# (361, 16)

# %%
# 1.3

# %%
data[data.is_first_time == 'Нет']['is_first_time'].count()
# Out:
# 51

# %%
df = pd.DataFrame([[1,'Bob', 'Builder'],
                  [2,'Sally', 'Baker'],
                  [3,'Scott', 'Candle Stick Maker']], 
columns=['id','name', 'occupation'])

# %%
index_to_drop = list(data[data.is_first_time == 'Нет'].sort_values(by="timestamp", ascending=False)[data.id.duplicated()].index)
index_to_drop
# Out:
# C:\Users\vasil\AppData\Local\Temp\ipykernel_6008\1480519640.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   index_to_drop = list(data[data.is_first_time == 'Нет'].sort_values(by="timestamp", ascending=False)[data.id.duplicated()].index)
# [204, 192, 342, 176, 325, 152, 150, 139, 126, 302, 98, 259, 30, 23]

# %%
data = data.drop(index_to_drop)

# %%
data.shape
# Out:
# (347, 16)

# %%
# 1.5
data.groupby(data.blended).count()["id"]
# Out:
# blended
#                                          213
# DevOps                                    87
# Введение в дифференциальную геометрию     15
# Соревновательный анализ данных            32
# Name: id, dtype: int64

# %%
data.groupby(by='blended').mean(numeric_only=True)["rating"]
# Out:
# blended
#                                           633.901408
# DevOps                                   1154.172414
# Введение в дифференциальную геометрию    1210.733333
# Соревновательный анализ данных           1144.218750
# Name: rating, dtype: float64

# %%
#1.6
data[data.duplicated(subset=["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3", "blended"], keep=False)]
# Out:
#                   timestamp                                id  rating  \
# 16  2020-05-15 16:58:06.959  64173586abab6f7a172946c8c74bde0d     630
# 40  2020-05-17 00:54:43.939  d38ebd0ba564ea88de8015e116f811c8     546
# 64  2020-05-18 11:13:13.920  b8d4c538f6b47a1a692bec6c2f29152b     682
# 67  2020-05-18 12:41:04.520  348562c4a55053de25fdd4389b9f1181     650
# 72  2020-05-18 14:44:19.586  fa4860bc719aadedbb00ba027067a8b7     642
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 84  2020-05-18 17:22:56.786  bfe75c08c6b7e31d4e7d48c9c5fed69b     758
# 88  2020-05-18 17:56:00.688  044e038535ae5d2ff037150b77fdc6d1     710
# 105 2020-05-18 19:25:39.947  5a6f07c1f6186408b43f0f8e729168e9     632
# 108 2020-05-18 19:35:49.258  1c1623a037bd523d687245e6060e6c5b     595
# 110 2020-05-18 19:36:51.479  f5d9f99cb876ca0888d18b6e444fa1b1     516
# 111 2020-05-18 19:49:54.661  b3eb1cdc4beffbdd5b29a8d54d649bc0     731
# ...

# %%
data[data.duplicated(subset=["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3", "blended"], keep=False)].groupby(["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3", "blended"]).count()
# Out:
#                                                                                                                                                                                                                                                                                                    timestamp  \
# fall_1                                          fall_2                                          fall_3                                          spring_1                                           spring_2                                    spring_3                                   blended
# Statistical Learning Theory                     Анализ неструктурированных данных               Сбор и обработка данных с помощью краудсорсинга Обучение с подкреплением                           Конфликты и кооперация                      Компьютерное зрение                        DevOps           2
# ...

# %%
 data[data.duplicated(subset=["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3", "blended"], keep=False)].groupby(["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3", "blended"]).count().shape[0]
# Out:
# 14

# %%
# 1.2
len(data[data["18_group"] != 0])
# Out:
# 213

# %%
len(data[data["17_group"] != 0])
# Out:
# 134

# %%
# 1.7
set(data.spring_1.unique()) == set(data.spring_2.unique())
# Out:
# True

# %%
data
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %%
data18 = data[(data["18_group"] != 0)]
data17 = data[(data["17_group"] != 0)]

# %%
set17 = set(pd.unique(data17[["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3"]].values.ravel()))

# %%
set18 = set(pd.unique(data18[["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3"]].values.ravel()))

# %%
set17.intersection(set18)
# Out:
# {'Statistical Learning Theory',
#  'Безопасность компьютерных систем',
#  'Высокопроизводительные вычисления',
#  'Моделирование временных рядов',
#  'Принятие решений в условиях риска и неопределённости',
#  'Сбор и обработка данных с помощью краудсорсинга',
#  'Численные методы'}

# %%
set17.difference(set18)
# Out:
# {'Анализ неструктурированных данных',
#  'Байесовские методы машинного обучения',
#  'Генеративные модели в машинном обучении',
#  'Глубинное обучение в обработке звука',
#  'Компьютерное зрение',
#  'Конфликты и кооперация',
#  'Методы сжатия и передачи медиаданных',
#  'Обучение с подкреплением',
#  'Проектирование и разработка высоконагруженных сервисов',
#  'Символьные вычисления'}

# %%
set18.difference(set17)
# Out:
# {'Анализ данных в бизнесе',
#  'Дискретная оптимизация',
#  'Дополнительные главы прикладной статистики',
#  'Компьютерные сети',
#  'Матричные вычисления',
#  'Машинное обучение 2',
#  'Промышленное программирование на языке Java',
#  'Системы баз данных',
#  'Теория баз данных',
#  'Язык SQL'}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# 1.8
data.timestamp.dt.day
# Out:
# 0      15
# 1      15
# 2      15
# 3      15
# 4      15
#        ..
# 356    19
# 357    19
# 358    20
# 359    23
# 360    23
# Name: timestamp, Length: 347, dtype: int32

# %%
data_ts_rt = data.groupby(data.timestamp.dt.day).mean(numeric_only=True)["rating"]

# %%
data_ts_rt
# Out:
# timestamp
# 14    1160.277778
# 15     719.866667
# 16     736.400000
# 17     915.027027
# 18     827.352679
# 19     761.142857
# 20     689.500000
# 21     584.000000
# 23    1080.500000
# 24     670.500000
# Name: rating, dtype: float64

# %%
list_ts = data_ts_rt.index
list_rt = data_ts_rt.values

# %%
fig,ax = plt.subplots()
fig.suptitle('Средний рейтинг')

ax.bar(list_ts, list_rt)
ax.yaxis.grid()
plt.show()

# %%
fig.savefig('mean_rating.pdf')

# %%
assert data.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert data.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %%
data["fall_num"] =( (data["17_group"] == 171) | (data["17_group"] == 172) | (data["17_group"] == 173) ).replace({True: 1, False: 0}) + ( (data["18_group"] > 0) & (data["is_mi"] > 0) ).replace({True: 1, False: 0}) + 1

# %%
col_name = "fall_num"   # insert your new column name as str

assert(data[data['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(data[data['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(data[data['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(data[data['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %%
data[data['fall_2'] == data['fall_3']]
# Out:
#                   timestamp                                id  rating  \
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# 239 2020-05-14 23:33:21.310  e0fceae1e285f737630bb6123a1bd85d    1203
# 283 2020-05-18 14:55:38.053  0d85933f07516e8871e9415c1d95ddbe    1202
# 295 2020-05-18 18:27:32.822  7fcf56aae6836855a689000a50e80360    1145
# 336 2020-05-18 23:01:42.225  842a87d59de90b711fe3266830fe608c    1188
# 349 2020-05-18 23:56:39.191  bb9bbd259ab6b8170a7dc6fb35695d13    1285
#
#      18_group  is_mi                                           fall_1  \
# 19      181.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 239       0.0    0.0                Высокопроизводительные вычисления
# 283       0.0    0.0                Высокопроизводительные вычисления
# 295       0.0    0.0                 Безопасность компьютерных систем
# 336       0.0    0.0                Высокопроизводительные вычисления
# ...

# %%
list17_18 = list(set17.union(set18))

# %%
list17_18
# Out:
# ['Безопасность компьютерных систем',
#  'Байесовские методы машинного обучения',
#  'Генеративные модели в машинном обучении',
#  'Принятие решений в условиях риска и неопределённости',
#  'Высокопроизводительные вычисления',
#  'Дискретная оптимизация',
#  'Промышленное программирование на языке Java',
#  'Символьные вычисления',
#  'Системы баз данных',
#  'Конфликты и кооперация',
#  'Моделирование временных рядов',
#  'Компьютерное зрение',
#  'Численные методы',
#  'Проектирование и разработка высоконагруженных сервисов',
#  'Методы сжатия и передачи медиаданных',
#  'Язык SQL',
#  'Сбор и обработка данных с помощью краудсорсинга',
#  'Statistical Learning Theory',
#  'Обучение с подкреплением',
#  'Анализ неструктурированных данных',
#  'Машинное обучение 2',
#  'Матричные вычисления',
#  'Теория баз данных',
#  'Анализ данных в бизнесе',
#  'Дополнительные главы прикладной статистики',
#  'Глубинное обучение в обработке звука',
#  'Компьютерные сети']

# %%
dfall = data
dfall.shape
# Out:
# (347, 17)

# %%
res_fall = pd.DataFrame(columns=['id', 'fall_1', 'fall_2', 'fall_3', 'fall_num', 'percentile', 'is_first_place', 'is_last_place'])

# %%
for course_name in list17_18:
    filter = (dfall['fall_1'] == course_name) | ((dfall['fall_num'] == 2) & (dfall['fall_2'] == course_name))
    places = 30
    if course_name in ('Statistical Learning Theory', 'Высокопроизводительные вычисления'):
        places = 60
    elif course_name == 'Анализ неструктурированных данных':
        places = 10000
    df_buf = dfall[filter][['id','fall_1', 'fall_2', 'fall_3', 'fall_num', 'percentile']].sort_values(by='percentile')[:places]
    df_buf['fall_1'] = df_buf['fall_1'].apply(lambda x: x if x == course_name else '')
    df_buf['fall_2'] = df_buf['fall_2'].apply(lambda x: x if x == course_name else '')
    res_fall = pd.concat([res_fall, df_buf], ignore_index=True)
    
res_fall
# Out:
#                                    id                                fall_1  \
# 0    3e106aaef8b24dbb01319c73e14c2936      Безопасность компьютерных систем
# 1    bfe75c08c6b7e31d4e7d48c9c5fed69b      Безопасность компьютерных систем
# 2    04f9a2dd035a040318ecd064959df3a0      Безопасность компьютерных систем
# 3    bb29d9b9230528a4873f91abce2095b8      Безопасность компьютерных систем
# 4    e5fb2c5a9d8a09915b15d14bf6cf3174      Безопасность компьютерных систем
# ..                                ...                                   ...
# 325  2ca6917be428f8b84f6f15cdcbea2143
# 326  e11399490117e1913ae79d09a5a2b981
# 327  7378a3c0caf8ce5fdbb1e4370b346cb7  Глубинное обучение в обработке звука
# 328  98c5a2548d93f26bd4195466e93178b3
# 329  d555d2805e1d93d4f023e57dc4c8f403
#
#                                    fall_2  \
# 0
# 1
# 2
# 3
# 4
# ..                                    ...
# 325  Глубинное обучение в обработке звука
# 326  Глубинное обучение в обработке звука
# 327
# ...

# %%
res_fall = res_fall.groupby('id').agg(lambda x: ''.join(x) if isinstance(x, str) else max(x)).reset_index()

# %%
filter = (res_fall['fall_1'] == res_fall['fall_3']) | (res_fall['fall_2'] == res_fall['fall_3'])
id_to_drop = res_fall[filter]['id'].values
dfall = dfall[~dfall['id'].isin(id_to_drop)]

# %%
filter = res_fall['fall_num'] == 1
id_to_drop = res_fall[filter]['id'].values
dfall = dfall[~dfall['id'].isin(id_to_drop)]

# %%
filter = (res_fall['fall_num'] == 2) & (res_fall['fall_1'] != '') & (res_fall['fall_2'] != '')
id_to_drop = res_fall[filter]['id'].values
dfall = dfall[~dfall['id'].isin(id_to_drop)]

# %%
res_fall
# Out:
#                                    id  \
# 0    01b072a0cdb45814fc4ab8ca3e621f0e
# 1    044e038535ae5d2ff037150b77fdc6d1
# 2    04b88fcbe5ba58aa8369c7de5e574de0
# 3    04bcb5c9d23813ffa940e1febb27fadc
# 4    04f9a2dd035a040318ecd064959df3a0
# ..                                ...
# 264  fe631bea98b075dd781e11df3987533b
# 265  fecff7bd30995d16b59fb392d47b3760
# 266  ff549c331d45453052f28ad2614afda9
# 267  ffc04c64d068f8d85e4dc44e7f297ecc
# 268  ffc58d371e2f52e1c7f45d49d3d629d0
#
#                                               fall_1  \
# 0                  Анализ неструктурированных данных
# 1                   Безопасность компьютерных систем
# 2                   Безопасность компьютерных систем
# 3                                  Теория баз данных
# 4                   Безопасность компьютерных систем
# ..                                               ...
# 264                      Statistical Learning Theory
# 265                Анализ неструктурированных данных
# ...

# %%
filter1 = (res_fall['fall_1'] == 'Байесовские методы машинного обучения') | (res_fall['fall_2'] == 'Байесовские методы машинного обучения')
res_fall[res_fall['id'] == res_fall[filter1].sort_values(by='percentile').iloc[0]['id']].index[0]
# Out:
# 94

# %%
for course_name in list17_18:
    filter1 = (res_fall['fall_1'] == course_name) | (res_fall['fall_2'] == course_name)
    if res_fall[filter1].shape[0] > 0:
        f_index = res_fall[res_fall['id'] == res_fall[filter1].sort_values(by='percentile').iloc[0]['id']].index[0]
        l_index = res_fall[res_fall['id'] == res_fall[filter1].sort_values(by='percentile').iloc[-1]['id']].index[0]
        res_fall.loc[f_index, 'is_first_place'] = True
        res_fall.loc[l_index, 'is_last_place'] = True

res_fall = res_fall.sort_values(by='percentile')

# %%
# import wget
# wget.download('https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0', '_2_task_check.csv')
check_df = pd.read_csv('_2_task_check.csv')

# %%
check_df.head(3)
# Out:
#                  timestamp                                id  rating  \
# 0  2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1  2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2  2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
#
#    18_group  is_mi                             fall_1  \
# 0     181.0    0.0                           Язык SQL
# 1     181.0    0.0  Высокопроизводительные вычисления
# 2     185.0    0.0   Безопасность компьютерных систем
#
#                               fall_2                         fall_3  \
# 0  Высокопроизводительные вычисления           Матричные вычисления
# 1   Безопасность компьютерных систем                       Язык SQL
# 2               Матричные вычисления  Моделирование временных рядов
#
#                  spring_1             spring_2             spring_3  \
# 0  Дискретная оптимизация     Численные методы  Машинное обучение 2
# ...

# %%
fir_col_name = 'is_first_place'
last_col_name = 'is_last_place'

df = res_fall

assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      == 
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[58], line 12
#       4 df = res_fall
#       6 assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       7         ==
#       8         check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       9        ).id.values).all()
# ---> 12 assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#      13       ==
#      14        check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#      15       ).id.values).all()
#
# AssertionError:

# %%
df_index = set(df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True).values.ravel())

# %%
cheak_df_index = set(check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True).values.ravel())

# %%
cheak_df_index.difference(df_index)
# Out:
# {'bf24738793f54467434ad78be13a42bf',
#  'c1e88502b6673d22c38ee1352e3a1dd9',
#  'feb53dcdd28fff9dc4a981c3419fea6f'}

# %%
data[data['id'].isin(cheak_df_index.difference(df_index))]
# Out:
#                   timestamp                                id  rating  \
# 100 2020-05-18 19:08:20.608  bf24738793f54467434ad78be13a42bf     693
# 135 2020-05-18 21:19:50.620  feb53dcdd28fff9dc4a981c3419fea6f     521
# 264 2020-05-17 18:04:39.903  c1e88502b6673d22c38ee1352e3a1dd9     985
#
#      18_group  is_mi                             fall_1  \
# 100     184.0    0.0   Безопасность компьютерных систем
# 135     186.0    1.0   Безопасность компьютерных систем
# 264       0.0    0.0  Анализ неструктурированных данных
#
#                             fall_2  \
# 100    Statistical Learning Theory
# 135                       Язык SQL
# 264  Моделирование временных рядов
#
#                                               fall_3  \
# 100                             Матричные вычисления
# 135  Сбор и обработка данных с помощью краудсорсинга
# 264  Сбор и обработка данных с помощью краудсорсинга
#
#                                         spring_1                 spring_2  \
# ...

# %%
check_df[check_df['id'].isin(cheak_df_index.difference(df_index))]
# Out:
#                    timestamp                                id  rating  \
# 97   2020-05-18 19:08:20.608  bf24738793f54467434ad78be13a42bf     693
# 130  2020-05-18 21:19:50.620  feb53dcdd28fff9dc4a981c3419fea6f     521
# 253  2020-05-17 18:04:39.903  c1e88502b6673d22c38ee1352e3a1dd9     985
#
#      18_group  is_mi                             fall_1  \
# 97      184.0    0.0   Безопасность компьютерных систем
# 130     186.0    1.0   Безопасность компьютерных систем
# 253       0.0    0.0  Анализ неструктурированных данных
#
#                             fall_2  \
# 97     Statistical Learning Theory
# 130                       Язык SQL
# 253  Моделирование временных рядов
#
#                                               fall_3  \
# 97                              Матричные вычисления
# 130  Сбор и обработка данных с помощью краудсорсинга
# 253  Сбор и обработка данных с помощью краудсорсинга
#
#                                         spring_1                 spring_2  \
# ...

# %%
cs = 'Безопасность компьютерных систем'
filter = (data['fall_1'] == cs) | ( (data['fall_num'] == 2) & (data['fall_2'] == cs) )
last_id_dt = data[filter].sort_values(by='percentile')[:30]['id'].iloc[-1]
last_id_rf = df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True).loc[0]

# %%
last_id_dt == last_id_rf
# Out:
# id    True
# Name: 0, dtype: bool

# %%
res_fall = res_fall.drop(['is_first_place', 'is_last_place'], axis=1)

# %%
res_fall = res_fall.fillna('')

# %%
res_fall.dtypes
# Out:
# id             object
# fall_1         object
# fall_2         object
# fall_3         object
# fall_num        int64
# percentile    float64
# dtype: object

# %%
# вторая волна распределения

for course_name in list17_18:
    df = dfall
    filter = ( (df['fall_num'] == 1) & (df['fall_2'] == course_name) ) | ( (df['fall_num'] == 2) & (df['fall_3'] == course_name) )
    places = 30 - res_fall[res_fall['fall_1'] == course_name].shape[0] - res_fall[res_fall['fall_2'] == course_name].shape[0]
    if course_name in ('Statistical Learning Theory', 'Высокопроизводительные вычисления'):
        places = 60 - res_fall[res_fall['fall_1'] == course_name].shape[0] - res_fall[res_fall['fall_2'] == course_name].shape[0]
    elif course_name == 'Анализ неструктурированных данных':
        places = 10000
    df_buf = df[filter][['id','fall_1', 'fall_2', 'fall_3', 'fall_num', 'percentile']].sort_values(by='percentile')[:places]
    df_buf['fall_1'] = df_buf['fall_1'].apply(lambda x: '')
    df_buf['fall_2'] = df_buf['fall_2'].apply(lambda x: x if x == course_name else '')
    df_buf['fall_3'] = df_buf['fall_3'].apply(lambda x: x if x == course_name else '')
    res_fall = pd.concat([res_fall, df_buf], ignore_index=True)
res_fall
# Out:
#                                    id  \
# 0    3a7326c9e355a67d3805824ca34c4bc5
# 1    3e106aaef8b24dbb01319c73e14c2936
# 2    e0ca1a9548af9a3f98428c62420aa484
# 3    7fe7df0d207babbf30249b3063ac1f26
# 4    86d929f6fd741e56e93cee5900298849
# ..                                ...
# 325  ba028043babda44219f3346809874ca3
# 326  7134f24c241836458335aa3abb8d8727
# 327  881b1a6fda195b354ae2edb396a69f5d
# 328  2e04f9bc8796f095ed7b9c7941df91a6
# 329  de539be8b29b3afa002184e28d63c670
#
#                                               fall_1  \
# 0                        Statistical Learning Theory
# 1                   Безопасность компьютерных систем
# 2                               Матричные вычисления
# 3                  Высокопроизводительные вычисления
# 4    Сбор и обработка данных с помощью краудсорсинга
# ..                                               ...
# 325
# 326
# 327
# 328
# 329
#
#                                               fall_2  \
# ...

# %%
res_fall = res_fall.fillna('')
res_fall.dtypes
# Out:
# id             object
# fall_1         object
# fall_2         object
# fall_3         object
# fall_num        int64
# percentile    float64
# dtype: object

# %%
res_fall = res_fall.groupby('id').agg(lambda x: ''.join(x) if isinstance(x, str) else max(x)).reset_index()

# %%
res_fall.dtypes
# Out:
# id             object
# fall_1         object
# fall_2         object
# fall_3         object
# fall_num        int64
# percentile    float64
# dtype: object

# %%
id_to_drop = res_fall['id'].values
dfall = dfall[~dfall['id'].isin(id_to_drop)]

# %%
# третья волна

for course_name in list17_18:
    df = dfall
    filter = (df['fall_num'] == 1) & (df['fall_3'] == course_name)
    places = 30 - res_fall[res_fall['fall_1'] == course_name].shape[0] - res_fall[res_fall['fall_2'] == course_name].shape[0] - res_fall[res_fall['fall_3'] == course_name].shape[0]
    if course_name in ('Statistical Learning Theory', 'Высокопроизводительные вычисления'):
        places = 60 - res_fall[res_fall['fall_1'] == course_name].shape[0] - res_fall[res_fall['fall_2'] == course_name].shape[0] - res_fall[res_fall['fall_3'] == course_name].shape[0]
    elif course_name == 'Анализ неструктурированных данных':
        places = 10000
    df_buf = df[filter][['id','fall_1', 'fall_2', 'fall_3', 'fall_num', 'percentile']].sort_values(by='percentile')[:places]
    df_buf['fall_1'] = df_buf['fall_1'].apply(lambda x: '')
    df_buf['fall_2'] = df_buf['fall_2'].apply(lambda x: '')
    df_buf['fall_3'] = df_buf['fall_3'].apply(lambda x: x if x == course_name else '')
    res_fall = pd.concat([res_fall, df_buf], ignore_index=True)
res_fall
# Out:
#                                    id                             fall_1  \
# 0    014b72217e20370dab7acc48b20c47be
# 1    01b072a0cdb45814fc4ab8ca3e621f0e  Анализ неструктурированных данных
# 2    044e038535ae5d2ff037150b77fdc6d1   Безопасность компьютерных систем
# 3    04b88fcbe5ba58aa8369c7de5e574de0   Безопасность компьютерных систем
# 4    04bcb5c9d23813ffa940e1febb27fadc                  Теория баз данных
# ..                                ...                                ...
# 313  253bbe1a2021d0404712a1e4acd22939
# 314  f2ed8115db45ef795ced2701fa86515d
# 315  8c3aa7371731bef999519c3de2c47423
# 316  1bbbfae51794b83c769b634be8da7b8d
# 317  aeb7bb1e047c392b7e5e39225cd86422
#
#                           fall_2                             fall_3  fall_num  \
# 0    Statistical Learning Theory                                            1
# 1                                     Моделирование временных рядов         2
# ...

# %%
id_to_drop = res_fall['id'].values
dfall = dfall[~dfall['id'].isin(id_to_drop)]

# %%
df = dfall
df_buf = df[['id','fall_1', 'fall_2', 'fall_3', 'fall_num', 'percentile']]
df_buf['fall_1'] = df_buf['fall_1'].apply(lambda x: '???')
df_buf['fall_2'] = df_buf['fall_2'].apply(lambda x: '')
df_buf['fall_3'] = df_buf['fall_3'].apply(lambda x: '')
res_fall = pd.concat([res_fall, df_buf], ignore_index=True)
# Out:
# C:\Users\vasil\AppData\Local\Temp\ipykernel_6008\3188429996.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_buf['fall_1'] = df_buf['fall_1'].apply(lambda x: '???')
# C:\Users\vasil\AppData\Local\Temp\ipykernel_6008\3188429996.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_buf['fall_2'] = df_buf['fall_2'].apply(lambda x: '')
# C:\Users\vasil\AppData\Local\Temp\ipykernel_6008\3188429996.py:5: SettingWithCopyWarning:
# ...

# %%
res_fall
# Out:
#                                    id                             fall_1  \
# 0    014b72217e20370dab7acc48b20c47be
# 1    01b072a0cdb45814fc4ab8ca3e621f0e  Анализ неструктурированных данных
# 2    044e038535ae5d2ff037150b77fdc6d1   Безопасность компьютерных систем
# 3    04b88fcbe5ba58aa8369c7de5e574de0   Безопасность компьютерных систем
# 4    04bcb5c9d23813ffa940e1febb27fadc                  Теория баз данных
# ..                                ...                                ...
# 342  180cf0e0dc7a6f88e76e3076cb761d26                                ???
# 343  7fcf56aae6836855a689000a50e80360                                ???
# 344  0c0cbdd1a309c1d1fd8993c4dc907bb5                                ???
# 345  0a3bf60d68e9bcb118ba4b472eabebc8                                ???
# 346  8fe79f84f36e3a5d2d6745621321302c                                ???
#
#                           fall_2                             fall_3  fall_num  \
# ...

# %%
def swap(col1, col2):
    cond = (res_fall[col1] == '') & (res_fall[col2] != '')
    res_fall.loc[cond, [col1, col2]] = res_fall.loc[cond, [col2, col1]].values

# %%
swap('fall_1', 'fall_2')
swap('fall_1', 'fall_3')
swap('fall_2', 'fall_3')

# %%
res_fall.loc[res_fall['fall_num'] == 1, 'fall_2'] = '-'
res_fall.loc[(res_fall['fall_num'] == 1) & (res_fall['fall_1'] == ''), 'fall_1'] = '???'
res_fall.loc[(res_fall['fall_num'] == 2) & (res_fall['fall_1'] == ''), 'fall_1'] = '???'
res_fall.loc[(res_fall['fall_num'] == 2) & (res_fall['fall_2'] == ''), 'fall_2'] = '???'

# %%
res_fall = res_fall.rename(columns={'fall_1': 'course1', 'fall_2': 'course2', 'id': 'ID'})

# %%
res_fall = res_fall.sort_values(by='percentile')
res_fall = res_fall[['ID', 'course1', 'course2']]

# %%
res_fall
# Out:
#                                    ID  \
# 61   3e106aaef8b24dbb01319c73e14c2936
# 56   3a7326c9e355a67d3805824ca34c4bc5
# 267  e0ca1a9548af9a3f98428c62420aa484
# 141  7fe7df0d207babbf30249b3063ac1f26
# 152  86d929f6fd741e56e93cee5900298849
# ..                                ...
# 133  79d14db48e4737af731960ae212d5134
# 339  40b18d40197e3db66312a026e06b8ff1
# 333  be4fa2120de3397ae21eac38ff0060e3
# 249  d539461bf254cf8b3201cdf7990b119e
# 135  7a21ef645ecb42198be493dd65320e78
#
#                                                course1  \
# 61                    Безопасность компьютерных систем
# 56                         Statistical Learning Theory
# 267                               Матричные вычисления
# 141                  Высокопроизводительные вычисления
# 152    Сбор и обработка данных с помощью краудсорсинга
# ..                                                 ...
# 133  Принятие решений в условиях риска и неопределё...
# ...

# %%
res_fall.to_csv('res_fall.csv', index=None)
